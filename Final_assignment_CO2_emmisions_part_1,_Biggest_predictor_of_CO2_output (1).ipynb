# %%
! pip install plotly==5.0.0
import plotly.express as px
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: plotly==5.0.0 in /usr/local/lib/python3.8/dist-packages (5.0.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from plotly==5.0.0) (8.1.0)
# Requirement already satisfied: six in /usr/local/lib/python3.8/dist-packages (from plotly==5.0.0) (1.15.0)

# %%
#import necesseary modules
import numpy as np
import matplotlib.pyplot as plt
import sys
import pandas as pd
import requests
import html5lib
import re
import bs4
from bs4 import BeautifulSoup
import csv
import os
from google.colab import drive
import glob
from scipy.stats import pearsonr
import scipy
import scipy.stats
from scipy.stats import t
import plotly.graph_objects as go
import plotly.express as px
import seaborn as sns
from functools import reduce
pd.set_option("display.max_rows", None, "display.max_columns", None)
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df1= pd.read_csv("/content/drive/MyDrive/csv files/capture-fisheries-vs-aquaculture.csv")
df1.head(5)
# Out:
#         Entity Code  Year  Aquaculture production (metric tons)  \
# 0  Afghanistan  AFG  1969                                  60.0
# 1  Afghanistan  AFG  1970                                  60.0
# 2  Afghanistan  AFG  1971                                  60.0
# 3  Afghanistan  AFG  1972                                  60.0
# 4  Afghanistan  AFG  1973                                  60.0
#
#    Capture fisheries production (metric tons)
# 0                                       400.0
# 1                                       400.0
# 2                                       500.0
# 3                                       500.0
# 4                                       500.0

# %%
df2 = pd.read_csv("/content/drive/MyDrive/csv files/cereal-yield.csv")
df2.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1961
# 1  Afghanistan  AFG  1962
# 2  Afghanistan  AFG  1963
# 3  Afghanistan  AFG  1964
# 4  Afghanistan  AFG  1965
#
#    Cereals | 00001717 || Yield | 005419 || tonnes per hectare
# 0                                             1.1151
# 1                                             1.0790
# 2                                             0.9858
# 3                                             1.0828
# 4                                             1.0989

# %%
df3= pd.read_csv("/content/drive/MyDrive/csv files/cost-healthy-diet.csv")
df3.head(5)
# Out:
#     Entity Code  Year  cost_healthy_diet
# 0  Albania  ALB  2017              3.952
# 1  Albania  ALB  2018              4.051
# 2  Albania  ALB  2019              4.117
# 3  Albania  ALB  2020              4.197
# 4  Algeria  DZA  2017              3.763

# %%
df4= pd.read_csv("/content/drive/MyDrive/csv files/dalys-rate-from-all-causes.csv")
df4.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    DALYs (Disability-Adjusted Life Years) - All causes - Sex: Both - Age: Age-standardized (Rate)
# 0                                           86375.17
# 1                                           83381.07
# 2                                           79890.55
# 3                                           80292.52
# 4                                           83334.93

# %%
df5= pd.read_csv("/content/drive/MyDrive/csv files/gdp-world-regions-stacked-area.csv")
df5.head(5)
# Out:
#         Entity Code  Year          GDP 417484-annotations
# 0  Afghanistan  AFG  1950   9421400064                NaN
# 1  Afghanistan  AFG  1951   9692279808                NaN
# 2  Afghanistan  AFG  1952  10017325056                NaN
# 3  Afghanistan  AFG  1953  10630519808                NaN
# 4  Afghanistan  AFG  1954  10866360320                NaN

# %%
df6= pd.read_csv("/content/drive/MyDrive/csv files/malnutrition-death-rates-by-age.csv")
df6.head(5)
# Out:
#         Entity Code  Year  \
# 0  Afghanistan  AFG  1990
# 1  Afghanistan  AFG  1991
# 2  Afghanistan  AFG  1992
# 3  Afghanistan  AFG  1993
# 4  Afghanistan  AFG  1994
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: Under 5 (Rate)  \
# 0                                              87.34
# 1                                              76.95
# 2                                              70.89
# 3                                              72.54
# 4                                              73.77
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 50-69 years (Rate)  \
# 0                                               3.34
# 1                                               3.38
# 2                                               3.44
# 3                                               3.57
# 4                                               3.72
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Rate)  \
# 0                                               2.75
# 1                                               2.66
# 2                                               2.56
# 3                                               2.58
# 4                                               2.63
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 5-14 years (Rate)  \
# 0                                               3.35
# 1                                               3.40
# 2                                               3.53
# 3                                               3.64
# 4                                               3.60
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 70+ years (Rate)  \
# 0                                               4.84
# 1                                               4.92
# 2                                               5.02
# 3                                               5.18
# 4                                               5.34
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                              11.04
# 1                                               9.93
# 2                                               9.34
# 3                                               9.75
# 4                                              10.13
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Rate)
# 0                                              17.99
# 1                                              16.84
# 2                                              16.53
# 3                                              17.50
# 4                                              18.16

# %%
df7= pd.read_csv("/content/drive/MyDrive/csv files/mdg3a-gpi-education.csv")
df7.head(5)
# Out:
#                 Entity  Code  Year  MDG3.A: gender parity index
# 0    Primary education   NaN  1991                         0.87
# 1    Primary education   NaN  2000                         0.91
# 2    Primary education   NaN  2015                         0.98
# 3  Secondary education   NaN  1991                         0.77
# 4  Secondary education   NaN  2000                         0.89

# %%
df8= pd.read_csv("/content/drive/MyDrive/csv files/number-acute-care-beds.csv")
df8.head(5)
# Out:
#     Entity Code  Year  Acute care beds (total number)
# 0  Austria  AUT  2005                         52870.0
# 1  Austria  AUT  2006                         52679.0
# 2  Austria  AUT  2007                         52922.0
# 3  Austria  AUT  2008                         52364.0
# 4  Austria  AUT  2009                         51967.0

# %%
#using directory
os.chdir("/content")

# %%
#find csv files
extension = 'csv'
all_filenames = all_filenames = [i for i in glob.glob("/content/drive/MyDrive/csv files/*.csv")]

# %%
#combine all files in the list
combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#export to csv
combined_csv.to_csv( "combined_csv.csv", index=False, encoding='utf-8-sig')
combined_csv.head(5)
# Out:
# <ipython-input-15-158ebca44638>:2: DtypeWarning: Columns (13) have mixed types.Specify dtype option on import or set low_memory=False.
#   combined_csv = pd.concat([pd.read_csv(f) for f in all_filenames ])
#         Entity Code  Year  Aquaculture production (metric tons)  \
# 0  Afghanistan  AFG  1969                                  60.0
# 1  Afghanistan  AFG  1970                                  60.0
# 2  Afghanistan  AFG  1971                                  60.0
# 3  Afghanistan  AFG  1972                                  60.0
# 4  Afghanistan  AFG  1973                                  60.0
#
#    Capture fisheries production (metric tons)  Acute care beds (total number)  \
# 0                                       400.0                             NaN
# 1                                       400.0                             NaN
# 2                                       500.0                             NaN
# 3                                       500.0                             NaN
# 4                                       500.0                             NaN
#
#    MDG3.A: gender parity index  \
# 0                          NaN
# 1                          NaN
# 2                          NaN
# 3                          NaN
# 4                          NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: Under 5 (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 50-69 years (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 5-14 years (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: 70+ years (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    GDP 417484-annotations  \
# 0  NaN                NaN
# 1  NaN                NaN
# 2  NaN                NaN
# 3  NaN                NaN
# 4  NaN                NaN
#
#    Cereals | 00001717 || Yield | 005419 || tonnes per hectare  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    DALYs (Disability-Adjusted Life Years) - All causes - Sex: Both - Age: Age-standardized (Rate)  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                                                NaN
#
#    cost_healthy_diet
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN

# %%
# applying groupby() function to
# group the data on entity value.
df_entities=combined_csv.groupby(['Entity']).mean()
df_entities.head(20)
# Out:
#                              Year  Aquaculture production (metric tons)  \
# Entity
# Afghanistan           1991.568982                           1131.000000
# Africa                1990.500000                                   NaN
# Africa (FAO)          1990.500000                                   NaN
# African Region (WHO)  2004.500000                                   NaN
# Albania               1989.993584                           1260.661017
# Algeria               1990.590361                            561.671627
# American Samoa        1995.953271                             12.500000
# Americas (FAO)        1990.500000                                   NaN
# Andorra               1999.195876                                   NaN
# Angola                1991.972821                            371.736842
# Anguilla              2017.000000                                   NaN
# Antigua and Barbuda   1995.578470                              9.750000
# Argentina             1979.407553                           1070.694998
# Armenia               2003.308588                           5126.741935
# Aruba                 1990.517685                              0.285714
# Asia                  1990.500000                                   NaN
# Asia (FAO)            1990.500000                                   NaN
# Australia             1956.758034                          28390.804489
# Austria               1972.479095                           2459.849154
# Azerbaijan            2003.308588                            709.874194
#
#                       Capture fisheries production (metric tons)  \
# Entity
# Afghanistan                                           895.762712
# Africa                                                       NaN
# Africa (FAO)                                                 NaN
# African Region (WHO)                                         NaN
# Albania                                              6115.879675
# Algeria                                             76079.020591
# American Samoa                                       1457.101695
# Americas (FAO)                                               NaN
# Andorra                                                 0.000000
# Angola                                             247447.084746
# Anguilla                                                     NaN
# Antigua and Barbuda                                  1833.881356
# Argentina                                          618050.118644
# Armenia                                              1558.483871
# Aruba                                                 359.406780
# Asia                                                         NaN
# Asia (FAO)                                                   NaN
# Australia                                          175831.612023
# Austria                                              1163.813559
# Azerbaijan                                          12550.064516
#
#                       Acute care beds (total number)  \
# Entity
# Afghanistan                                      NaN
# Africa                                           NaN
# Africa (FAO)                                     NaN
# African Region (WHO)                             NaN
# Albania                                          NaN
# Algeria                                          NaN
# American Samoa                                   NaN
# Americas (FAO)                                   NaN
# Andorra                                          NaN
# Angola                                           NaN
# Anguilla                                         NaN
# Antigua and Barbuda                              NaN
# Argentina                                        NaN
# Armenia                                          NaN
# Aruba                                            NaN
# Asia                                             NaN
# Asia (FAO)                                       NaN
# Australia                                        NaN
# Austria                                 50805.769231
# Azerbaijan                                       NaN
#
#                       MDG3.A: gender parity index  \
# Entity
# Afghanistan                                   NaN
# Africa                                        NaN
# Africa (FAO)                                  NaN
# African Region (WHO)                          NaN
# Albania                                       NaN
# Algeria                                       NaN
# American Samoa                                NaN
# Americas (FAO)                                NaN
# Andorra                                       NaN
# Angola                                        NaN
# Anguilla                                      NaN
# Antigua and Barbuda                           NaN
# Argentina                                     NaN
# Armenia                                       NaN
# Aruba                                         NaN
# Asia                                          NaN
# Asia (FAO)                                    NaN
# Australia                                     NaN
# Austria                                       NaN
# Azerbaijan                                    NaN
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: Under 5 (Rate)  \
# Entity
# Afghanistan                                                   47.210000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                         101.867333
# Albania                                                        4.507667
# Algeria                                                        3.452333
# American Samoa                                                 7.798667
# Americas (FAO)                                                      NaN
# Andorra                                                        0.011667
# Angola                                                       221.544333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            5.561667
# Argentina                                                      7.099000
# Armenia                                                        0.142333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.043000
# Austria                                                        0.010000
# Azerbaijan                                                     4.954667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 50-69 years (Rate)  \
# Entity
# Afghanistan                                                    2.920667
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          17.258333
# Albania                                                        0.102667
# Algeria                                                        0.366333
# American Samoa                                                 2.476333
# Americas (FAO)                                                      NaN
# Andorra                                                        0.030000
# Angola                                                        37.484000
# Anguilla                                                            NaN
# Antigua and Barbuda                                            3.695667
# Argentina                                                      2.872333
# Armenia                                                        0.372000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.232333
# Austria                                                        0.010333
# Azerbaijan                                                     0.432667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Rate)  \
# Entity
# Afghanistan                                                    2.080000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                           2.607667
# Albania                                                        0.023000
# Algeria                                                        0.117333
# American Samoa                                                 0.298667
# Americas (FAO)                                                      NaN
# Andorra                                                        0.010000
# Angola                                                         5.019667
# Anguilla                                                            NaN
# Antigua and Barbuda                                            0.523333
# Argentina                                                      0.294000
# Armenia                                                        0.404000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.025000
# Austria                                                        0.010000
# Azerbaijan                                                     0.120000
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 5-14 years (Rate)  \
# Entity
# Afghanistan                                                    2.467000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                           3.226667
# Albania                                                        0.076667
# Algeria                                                        0.222000
# American Samoa                                                 0.413667
# Americas (FAO)                                                      NaN
# Andorra                                                        0.007667
# Angola                                                         5.359333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            0.429333
# Argentina                                                      0.281333
# Armenia                                                        0.057333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.005000
# Austria                                                        0.004667
# Azerbaijan                                                     0.088333
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 70+ years (Rate)  \
# Entity
# Afghanistan                                                    4.251333
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                         103.328333
# Albania                                                        0.635667
# Algeria                                                        4.813000
# American Samoa                                                69.815000
# Americas (FAO)                                                      NaN
# Andorra                                                        1.170667
# Angola                                                       197.910333
# Anguilla                                                            NaN
# Antigua and Barbuda                                           43.510667
# Argentina                                                     33.984333
# Armenia                                                        0.686333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      4.397667
# Austria                                                        0.088333
# Azerbaijan                                                     1.049000
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: Age-standardized (Rate)  \
# Entity
# Afghanistan                                                    6.902000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          22.438000
# Albania                                                        0.539000
# Algeria                                                        1.049000
# American Samoa                                                 7.349000
# Americas (FAO)                                                      NaN
# Andorra                                                        0.085667
# Angola                                                        47.490333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            4.084333
# Argentina                                                      3.484667
# Armenia                                                        0.335000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.318667
# Austria                                                        0.010333
# Azerbaijan                                                     0.737667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Rate)  \
# Entity
# Afghanistan                                                   11.141000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          22.952000
# Albania                                                        0.532667
# Algeria                                                        0.702333
# American Samoa                                                 3.471333
# Americas (FAO)                                                      NaN
# Andorra                                                        0.113333
# Angola                                                        51.441333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            3.587000
# Argentina                                                      3.641667
# Armenia                                                        0.325333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.469333
# Austria                                                        0.016667
# Azerbaijan                                                     0.678667
#
#                                GDP  \
# Entity
# Afghanistan           2.146437e+10
# Africa                         NaN
# Africa (FAO)                   NaN
# African Region (WHO)           NaN
# Albania               1.160662e+10
# Algeria               1.628369e+11
# American Samoa                 NaN
# Americas (FAO)                 NaN
# Andorra                        NaN
# Angola                3.792500e+10
# Anguilla                       NaN
# Antigua and Barbuda            NaN
# Argentina             2.595960e+11
# Armenia               2.526428e+10
# Aruba                          NaN
# Asia                           NaN
# Asia (FAO)                     NaN
# Australia             1.840341e+11
# Austria               1.010756e+11
# Azerbaijan            7.642295e+10
#
#                       Cereals | 00001717 || Yield | 005419 || tonnes per hectare  \
# Entity
# Afghanistan                                                    1.416355
# Africa                                                         1.246256
# Africa (FAO)                                                   1.207272
# African Region (WHO)                                                NaN
# Albania                                                        2.922538
# Algeria                                                        0.949113
# American Samoa                                                      NaN
# Americas (FAO)                                                 3.754633
# Andorra                                                             NaN
# Angola                                                         0.641300
# Anguilla                                                            NaN
# Antigua and Barbuda                                            1.881207
# Argentina                                                      2.951693
# Armenia                                                        2.129600
# Aruba                                                               NaN
# Asia                                                           2.702715
# Asia (FAO)                                                     2.702527
# Australia                                                      1.597162
# Austria                                                        4.995922
# Azerbaijan                                                     2.429055
#
#                       DALYs (Disability-Adjusted Life Years) - All causes - Sex: Both - Age: Age-standardized (Rate)  \
# Entity
# Afghanistan                                                71731.817333
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                       71840.571333
# Albania                                                    27015.075667
# Algeria                                                    34263.772667
# American Samoa                                             34025.049667
# Americas (FAO)                                                      NaN
# Andorra                                                    20211.926667
# Angola                                                     74916.238667
# Anguilla                                                            NaN
# Antigua and Barbuda                                        27536.639667
# Argentina                                                  28606.526000
# Armenia                                                    31526.874667
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                  21930.998333
# Austria                                                    22291.806667
# Azerbaijan                                                 42874.789667
#
#                       cost_healthy_diet
# Entity
# Afghanistan                         NaN
# Africa                              NaN
# Africa (FAO)                        NaN
# African Region (WHO)                NaN
# Albania                         4.07925
# Algeria                         3.78525
# American Samoa                      NaN
# Americas (FAO)                      NaN
# Andorra                             NaN
# Angola                          4.37650
# Anguilla                        3.71700
# Antigua and Barbuda             4.32725
# Argentina                       3.34100
# Armenia                         3.18650
# Aruba                           3.77075
# Asia                                NaN
# Asia (FAO)                          NaN
# Australia                       2.35450
# Austria                         2.85475
# Azerbaijan                      2.43475

# %%
#drop duplicates
df_doubles = df_entities.drop_duplicates(subset=list(df_entities.columns))
print(df_entities.shape)
df_doubles.head(20)
# Out:
# (328, 16)
#                              Year  Aquaculture production (metric tons)  \
# Entity
# Afghanistan           1991.568982                           1131.000000
# Africa                1990.500000                                   NaN
# Africa (FAO)          1990.500000                                   NaN
# African Region (WHO)  2004.500000                                   NaN
# Albania               1989.993584                           1260.661017
# Algeria               1990.590361                            561.671627
# American Samoa        1995.953271                             12.500000
# Americas (FAO)        1990.500000                                   NaN
# Andorra               1999.195876                                   NaN
# Angola                1991.972821                            371.736842
# Anguilla              2017.000000                                   NaN
# Antigua and Barbuda   1995.578470                              9.750000
# Argentina             1979.407553                           1070.694998
# Armenia               2003.308588                           5126.741935
# Aruba                 1990.517685                              0.285714
# Asia                  1990.500000                                   NaN
# Asia (FAO)            1990.500000                                   NaN
# Australia             1956.758034                          28390.804489
# Austria               1972.479095                           2459.849154
# Azerbaijan            2003.308588                            709.874194
#
#                       Capture fisheries production (metric tons)  \
# Entity
# Afghanistan                                           895.762712
# Africa                                                       NaN
# Africa (FAO)                                                 NaN
# African Region (WHO)                                         NaN
# Albania                                              6115.879675
# Algeria                                             76079.020591
# American Samoa                                       1457.101695
# Americas (FAO)                                               NaN
# Andorra                                                 0.000000
# Angola                                             247447.084746
# Anguilla                                                     NaN
# Antigua and Barbuda                                  1833.881356
# Argentina                                          618050.118644
# Armenia                                              1558.483871
# Aruba                                                 359.406780
# Asia                                                         NaN
# Asia (FAO)                                                   NaN
# Australia                                          175831.612023
# Austria                                              1163.813559
# Azerbaijan                                          12550.064516
#
#                       Acute care beds (total number)  \
# Entity
# Afghanistan                                      NaN
# Africa                                           NaN
# Africa (FAO)                                     NaN
# African Region (WHO)                             NaN
# Albania                                          NaN
# Algeria                                          NaN
# American Samoa                                   NaN
# Americas (FAO)                                   NaN
# Andorra                                          NaN
# Angola                                           NaN
# Anguilla                                         NaN
# Antigua and Barbuda                              NaN
# Argentina                                        NaN
# Armenia                                          NaN
# Aruba                                            NaN
# Asia                                             NaN
# Asia (FAO)                                       NaN
# Australia                                        NaN
# Austria                                 50805.769231
# Azerbaijan                                       NaN
#
#                       MDG3.A: gender parity index  \
# Entity
# Afghanistan                                   NaN
# Africa                                        NaN
# Africa (FAO)                                  NaN
# African Region (WHO)                          NaN
# Albania                                       NaN
# Algeria                                       NaN
# American Samoa                                NaN
# Americas (FAO)                                NaN
# Andorra                                       NaN
# Angola                                        NaN
# Anguilla                                      NaN
# Antigua and Barbuda                           NaN
# Argentina                                     NaN
# Armenia                                       NaN
# Aruba                                         NaN
# Asia                                          NaN
# Asia (FAO)                                    NaN
# Australia                                     NaN
# Austria                                       NaN
# Azerbaijan                                    NaN
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: Under 5 (Rate)  \
# Entity
# Afghanistan                                                   47.210000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                         101.867333
# Albania                                                        4.507667
# Algeria                                                        3.452333
# American Samoa                                                 7.798667
# Americas (FAO)                                                      NaN
# Andorra                                                        0.011667
# Angola                                                       221.544333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            5.561667
# Argentina                                                      7.099000
# Armenia                                                        0.142333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.043000
# Austria                                                        0.010000
# Azerbaijan                                                     4.954667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 50-69 years (Rate)  \
# Entity
# Afghanistan                                                    2.920667
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          17.258333
# Albania                                                        0.102667
# Algeria                                                        0.366333
# American Samoa                                                 2.476333
# Americas (FAO)                                                      NaN
# Andorra                                                        0.030000
# Angola                                                        37.484000
# Anguilla                                                            NaN
# Antigua and Barbuda                                            3.695667
# Argentina                                                      2.872333
# Armenia                                                        0.372000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.232333
# Austria                                                        0.010333
# Azerbaijan                                                     0.432667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Rate)  \
# Entity
# Afghanistan                                                    2.080000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                           2.607667
# Albania                                                        0.023000
# Algeria                                                        0.117333
# American Samoa                                                 0.298667
# Americas (FAO)                                                      NaN
# Andorra                                                        0.010000
# Angola                                                         5.019667
# Anguilla                                                            NaN
# Antigua and Barbuda                                            0.523333
# Argentina                                                      0.294000
# Armenia                                                        0.404000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.025000
# Austria                                                        0.010000
# Azerbaijan                                                     0.120000
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 5-14 years (Rate)  \
# Entity
# Afghanistan                                                    2.467000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                           3.226667
# Albania                                                        0.076667
# Algeria                                                        0.222000
# American Samoa                                                 0.413667
# Americas (FAO)                                                      NaN
# Andorra                                                        0.007667
# Angola                                                         5.359333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            0.429333
# Argentina                                                      0.281333
# Armenia                                                        0.057333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.005000
# Austria                                                        0.004667
# Azerbaijan                                                     0.088333
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: 70+ years (Rate)  \
# Entity
# Afghanistan                                                    4.251333
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                         103.328333
# Albania                                                        0.635667
# Algeria                                                        4.813000
# American Samoa                                                69.815000
# Americas (FAO)                                                      NaN
# Andorra                                                        1.170667
# Angola                                                       197.910333
# Anguilla                                                            NaN
# Antigua and Barbuda                                           43.510667
# Argentina                                                     33.984333
# Armenia                                                        0.686333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      4.397667
# Austria                                                        0.088333
# Azerbaijan                                                     1.049000
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: Age-standardized (Rate)  \
# Entity
# Afghanistan                                                    6.902000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          22.438000
# Albania                                                        0.539000
# Algeria                                                        1.049000
# American Samoa                                                 7.349000
# Americas (FAO)                                                      NaN
# Andorra                                                        0.085667
# Angola                                                        47.490333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            4.084333
# Argentina                                                      3.484667
# Armenia                                                        0.335000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.318667
# Austria                                                        0.010333
# Azerbaijan                                                     0.737667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Rate)  \
# Entity
# Afghanistan                                                   11.141000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          22.952000
# Albania                                                        0.532667
# Algeria                                                        0.702333
# American Samoa                                                 3.471333
# Americas (FAO)                                                      NaN
# Andorra                                                        0.113333
# Angola                                                        51.441333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            3.587000
# Argentina                                                      3.641667
# Armenia                                                        0.325333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.469333
# Austria                                                        0.016667
# Azerbaijan                                                     0.678667
#
#                                GDP  \
# Entity
# Afghanistan           2.146437e+10
# Africa                         NaN
# Africa (FAO)                   NaN
# African Region (WHO)           NaN
# Albania               1.160662e+10
# Algeria               1.628369e+11
# American Samoa                 NaN
# Americas (FAO)                 NaN
# Andorra                        NaN
# Angola                3.792500e+10
# Anguilla                       NaN
# Antigua and Barbuda            NaN
# Argentina             2.595960e+11
# Armenia               2.526428e+10
# Aruba                          NaN
# Asia                           NaN
# Asia (FAO)                     NaN
# Australia             1.840341e+11
# Austria               1.010756e+11
# Azerbaijan            7.642295e+10
#
#                       Cereals | 00001717 || Yield | 005419 || tonnes per hectare  \
# Entity
# Afghanistan                                                    1.416355
# Africa                                                         1.246256
# Africa (FAO)                                                   1.207272
# African Region (WHO)                                                NaN
# Albania                                                        2.922538
# Algeria                                                        0.949113
# American Samoa                                                      NaN
# Americas (FAO)                                                 3.754633
# Andorra                                                             NaN
# Angola                                                         0.641300
# Anguilla                                                            NaN
# Antigua and Barbuda                                            1.881207
# Argentina                                                      2.951693
# Armenia                                                        2.129600
# Aruba                                                               NaN
# Asia                                                           2.702715
# Asia (FAO)                                                     2.702527
# Australia                                                      1.597162
# Austria                                                        4.995922
# Azerbaijan                                                     2.429055
#
#                       DALYs (Disability-Adjusted Life Years) - All causes - Sex: Both - Age: Age-standardized (Rate)  \
# Entity
# Afghanistan                                                71731.817333
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                       71840.571333
# Albania                                                    27015.075667
# Algeria                                                    34263.772667
# American Samoa                                             34025.049667
# Americas (FAO)                                                      NaN
# Andorra                                                    20211.926667
# Angola                                                     74916.238667
# Anguilla                                                            NaN
# Antigua and Barbuda                                        27536.639667
# Argentina                                                  28606.526000
# Armenia                                                    31526.874667
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                  21930.998333
# Austria                                                    22291.806667
# Azerbaijan                                                 42874.789667
#
#                       cost_healthy_diet
# Entity
# Afghanistan                         NaN
# Africa                              NaN
# Africa (FAO)                        NaN
# African Region (WHO)                NaN
# Albania                         4.07925
# Algeria                         3.78525
# American Samoa                      NaN
# Americas (FAO)                      NaN
# Andorra                             NaN
# Angola                          4.37650
# Anguilla                        3.71700
# Antigua and Barbuda             4.32725
# Argentina                       3.34100
# Armenia                         3.18650
# Aruba                           3.77075
# Asia                                NaN
# Asia (FAO)                          NaN
# Australia                       2.35450
# Austria                         2.85475
# Azerbaijan                      2.43475

# %%
#drop year in dataframe
df_doubles.drop(['Deaths - Protein-energy malnutrition - Sex: Both - Age: Under 5 (Rate)',	
                 'Deaths - Protein-energy malnutrition - Sex: Both - Age: 50-69 years (Rate)',
                 'Deaths - Protein-energy malnutrition - Sex: Both - Age: 15-49 years (Rate)',	
                 'Deaths - Protein-energy malnutrition - Sex: Both - Age: 5-14 years (Rate)',
                 'Deaths - Protein-energy malnutrition - Sex: Both - Age: 70+ years (Rate)', 'Year'], axis = 1 , inplace=True)
df_doubles.head(20)
# Out:
#                       Aquaculture production (metric tons)  \
# Entity
# Afghanistan                                    1131.000000
# Africa                                                 NaN
# Africa (FAO)                                           NaN
# African Region (WHO)                                   NaN
# Albania                                        1260.661017
# Algeria                                         561.671627
# American Samoa                                   12.500000
# Americas (FAO)                                         NaN
# Andorra                                                NaN
# Angola                                          371.736842
# Anguilla                                               NaN
# Antigua and Barbuda                               9.750000
# Argentina                                      1070.694998
# Armenia                                        5126.741935
# Aruba                                             0.285714
# Asia                                                   NaN
# Asia (FAO)                                             NaN
# Australia                                     28390.804489
# Austria                                        2459.849154
# Azerbaijan                                      709.874194
#
#                       Capture fisheries production (metric tons)  \
# Entity
# Afghanistan                                           895.762712
# Africa                                                       NaN
# Africa (FAO)                                                 NaN
# African Region (WHO)                                         NaN
# Albania                                              6115.879675
# Algeria                                             76079.020591
# American Samoa                                       1457.101695
# Americas (FAO)                                               NaN
# Andorra                                                 0.000000
# Angola                                             247447.084746
# Anguilla                                                     NaN
# Antigua and Barbuda                                  1833.881356
# Argentina                                          618050.118644
# Armenia                                              1558.483871
# Aruba                                                 359.406780
# Asia                                                         NaN
# Asia (FAO)                                                   NaN
# Australia                                          175831.612023
# Austria                                              1163.813559
# Azerbaijan                                          12550.064516
#
#                       Acute care beds (total number)  \
# Entity
# Afghanistan                                      NaN
# Africa                                           NaN
# Africa (FAO)                                     NaN
# African Region (WHO)                             NaN
# Albania                                          NaN
# Algeria                                          NaN
# American Samoa                                   NaN
# Americas (FAO)                                   NaN
# Andorra                                          NaN
# Angola                                           NaN
# Anguilla                                         NaN
# Antigua and Barbuda                              NaN
# Argentina                                        NaN
# Armenia                                          NaN
# Aruba                                            NaN
# Asia                                             NaN
# Asia (FAO)                                       NaN
# Australia                                        NaN
# Austria                                 50805.769231
# Azerbaijan                                       NaN
#
#                       MDG3.A: gender parity index  \
# Entity
# Afghanistan                                   NaN
# Africa                                        NaN
# Africa (FAO)                                  NaN
# African Region (WHO)                          NaN
# Albania                                       NaN
# Algeria                                       NaN
# American Samoa                                NaN
# Americas (FAO)                                NaN
# Andorra                                       NaN
# Angola                                        NaN
# Anguilla                                      NaN
# Antigua and Barbuda                           NaN
# Argentina                                     NaN
# Armenia                                       NaN
# Aruba                                         NaN
# Asia                                          NaN
# Asia (FAO)                                    NaN
# Australia                                     NaN
# Austria                                       NaN
# Azerbaijan                                    NaN
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: Age-standardized (Rate)  \
# Entity
# Afghanistan                                                    6.902000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          22.438000
# Albania                                                        0.539000
# Algeria                                                        1.049000
# American Samoa                                                 7.349000
# Americas (FAO)                                                      NaN
# Andorra                                                        0.085667
# Angola                                                        47.490333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            4.084333
# Argentina                                                      3.484667
# Armenia                                                        0.335000
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.318667
# Austria                                                        0.010333
# Azerbaijan                                                     0.737667
#
#                       Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Rate)  \
# Entity
# Afghanistan                                                   11.141000
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                          22.952000
# Albania                                                        0.532667
# Algeria                                                        0.702333
# American Samoa                                                 3.471333
# Americas (FAO)                                                      NaN
# Andorra                                                        0.113333
# Angola                                                        51.441333
# Anguilla                                                            NaN
# Antigua and Barbuda                                            3.587000
# Argentina                                                      3.641667
# Armenia                                                        0.325333
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                      0.469333
# Austria                                                        0.016667
# Azerbaijan                                                     0.678667
#
#                                GDP  \
# Entity
# Afghanistan           2.146437e+10
# Africa                         NaN
# Africa (FAO)                   NaN
# African Region (WHO)           NaN
# Albania               1.160662e+10
# Algeria               1.628369e+11
# American Samoa                 NaN
# Americas (FAO)                 NaN
# Andorra                        NaN
# Angola                3.792500e+10
# Anguilla                       NaN
# Antigua and Barbuda            NaN
# Argentina             2.595960e+11
# Armenia               2.526428e+10
# Aruba                          NaN
# Asia                           NaN
# Asia (FAO)                     NaN
# Australia             1.840341e+11
# Austria               1.010756e+11
# Azerbaijan            7.642295e+10
#
#                       Cereals | 00001717 || Yield | 005419 || tonnes per hectare  \
# Entity
# Afghanistan                                                    1.416355
# Africa                                                         1.246256
# Africa (FAO)                                                   1.207272
# African Region (WHO)                                                NaN
# Albania                                                        2.922538
# Algeria                                                        0.949113
# American Samoa                                                      NaN
# Americas (FAO)                                                 3.754633
# Andorra                                                             NaN
# Angola                                                         0.641300
# Anguilla                                                            NaN
# Antigua and Barbuda                                            1.881207
# Argentina                                                      2.951693
# Armenia                                                        2.129600
# Aruba                                                               NaN
# Asia                                                           2.702715
# Asia (FAO)                                                     2.702527
# Australia                                                      1.597162
# Austria                                                        4.995922
# Azerbaijan                                                     2.429055
#
#                       DALYs (Disability-Adjusted Life Years) - All causes - Sex: Both - Age: Age-standardized (Rate)  \
# Entity
# Afghanistan                                                71731.817333
# Africa                                                              NaN
# Africa (FAO)                                                        NaN
# African Region (WHO)                                       71840.571333
# Albania                                                    27015.075667
# Algeria                                                    34263.772667
# American Samoa                                             34025.049667
# Americas (FAO)                                                      NaN
# Andorra                                                    20211.926667
# Angola                                                     74916.238667
# Anguilla                                                            NaN
# Antigua and Barbuda                                        27536.639667
# Argentina                                                  28606.526000
# Armenia                                                    31526.874667
# Aruba                                                               NaN
# Asia                                                                NaN
# Asia (FAO)                                                          NaN
# Australia                                                  21930.998333
# Austria                                                    22291.806667
# Azerbaijan                                                 42874.789667
#
#                       cost_healthy_diet
# Entity
# Afghanistan                         NaN
# Africa                              NaN
# Africa (FAO)                        NaN
# African Region (WHO)                NaN
# Albania                         4.07925
# Algeria                         3.78525
# American Samoa                      NaN
# Americas (FAO)                      NaN
# Andorra                             NaN
# Angola                          4.37650
# Anguilla                        3.71700
# Antigua and Barbuda             4.32725
# Argentina                       3.34100
# Armenia                         3.18650
# Aruba                           3.77075
# Asia                                NaN
# Asia (FAO)                          NaN
# Australia                       2.35450
# Austria                         2.85475
# Azerbaijan                      2.43475

# %%
#rename columns for better readable examples
# Or rename the existing DataFrame (rather than creating a copy) 
df_doubles.rename(columns={'Aquaculture production (metric tons)': 'aquaculture', 'Capture fisheries production (metric tons)': 'capture fish', 'Acute care beds (total number)': 'acute care',
                   'MDG3.A: gender parity index':'gender parity', 'Deaths - Protein-energy malnutrition - Sex: Both - Age: Age-standardized (Rate)':'malnutrition standard age',
                   'Deaths - Protein-energy malnutrition - Sex: Both - Age: All Ages (Rate)': 'malnutrition all ages', 'GDP': 'gdp', 'Cereals | 00001717 || Yield | 005419 || tonnes per hectare': 'cereals',
                   'DALYs (Disability-Adjusted Life Years) - All causes - Sex: Both - Age: Age-standardized (Rate)': 'disability life years', 'cost_healthy_diet': 'healthy diet'}, inplace=True)

# %%
#remove nan values using fillna and mean function
df_mean_values = df_doubles.fillna(df_doubles.mean())
df_mean_values.head(20)
# Out:
#                         aquaculture  capture fish     acute care  \
# Entity
# Afghanistan             1131.000000  8.957627e+02  223244.138099
# Africa                885460.188399  1.696111e+06  223244.138099
# Africa (FAO)          885460.188399  1.696111e+06  223244.138099
# African Region (WHO)  885460.188399  1.696111e+06  223244.138099
# Albania                 1260.661017  6.115880e+03  223244.138099
# Algeria                  561.671627  7.607902e+04  223244.138099
# American Samoa            12.500000  1.457102e+03  223244.138099
# Americas (FAO)        885460.188399  1.696111e+06  223244.138099
# Andorra               885460.188399  0.000000e+00  223244.138099
# Angola                   371.736842  2.474471e+05  223244.138099
# Anguilla              885460.188399  1.696111e+06  223244.138099
# Antigua and Barbuda        9.750000  1.833881e+03  223244.138099
# Argentina               1070.694998  6.180501e+05  223244.138099
# Armenia                 5126.741935  1.558484e+03  223244.138099
# Aruba                      0.285714  3.594068e+02  223244.138099
# Asia                  885460.188399  1.696111e+06  223244.138099
# Asia (FAO)            885460.188399  1.696111e+06  223244.138099
# Australia              28390.804489  1.758316e+05  223244.138099
# Austria                 2459.849154  1.163814e+03   50805.769231
# Azerbaijan               709.874194  1.255006e+04  223244.138099
#
#                       gender parity  malnutrition standard age  \
# Entity
# Afghanistan                0.885556                   6.902000
# Africa                     0.885556                   9.633624
# Africa (FAO)               0.885556                   9.633624
# African Region (WHO)       0.885556                  22.438000
# Albania                    0.885556                   0.539000
# Algeria                    0.885556                   1.049000
# American Samoa             0.885556                   7.349000
# Americas (FAO)             0.885556                   9.633624
# Andorra                    0.885556                   0.085667
# Angola                     0.885556                  47.490333
# Anguilla                   0.885556                   9.633624
# Antigua and Barbuda        0.885556                   4.084333
# Argentina                  0.885556                   3.484667
# Armenia                    0.885556                   0.335000
# Aruba                      0.885556                   9.633624
# Asia                       0.885556                   9.633624
# Asia (FAO)                 0.885556                   9.633624
# Australia                  0.885556                   0.318667
# Austria                    0.885556                   0.010333
# Azerbaijan                 0.885556                   0.737667
#
#                       malnutrition all ages           gdp   cereals  \
# Entity
# Afghanistan                       11.141000  2.146437e+10  1.416355
# Africa                             8.571427  5.985399e+11  1.246256
# Africa (FAO)                       8.571427  5.985399e+11  1.207272
# African Region (WHO)              22.952000  5.985399e+11  2.564712
# Albania                            0.532667  1.160662e+10  2.922538
# Algeria                            0.702333  1.628369e+11  0.949113
# American Samoa                     3.471333  5.985399e+11  2.564712
# Americas (FAO)                     8.571427  5.985399e+11  3.754633
# Andorra                            0.113333  5.985399e+11  2.564712
# Angola                            51.441333  3.792500e+10  0.641300
# Anguilla                           8.571427  5.985399e+11  2.564712
# Antigua and Barbuda                3.587000  5.985399e+11  1.881207
# Argentina                          3.641667  2.595960e+11  2.951693
# Armenia                            0.325333  2.526428e+10  2.129600
# Aruba                              8.571427  5.985399e+11  2.564712
# Asia                               8.571427  5.985399e+11  2.702715
# Asia (FAO)                         8.571427  5.985399e+11  2.702527
# Australia                          0.469333  1.840341e+11  1.597162
# Austria                            0.016667  1.010756e+11  4.995922
# Azerbaijan                         0.678667  7.642295e+10  2.429055
#
#                       disability life years  healthy diet
# Entity
# Afghanistan                    71731.817333      3.416433
# Africa                         42372.219173      3.416433
# Africa (FAO)                   42372.219173      3.416433
# African Region (WHO)           71840.571333      3.416433
# Albania                        27015.075667      4.079250
# Algeria                        34263.772667      3.785250
# American Samoa                 34025.049667      3.416433
# Americas (FAO)                 42372.219173      3.416433
# Andorra                        20211.926667      3.416433
# Angola                         74916.238667      4.376500
# Anguilla                       42372.219173      3.717000
# Antigua and Barbuda            27536.639667      4.327250
# Argentina                      28606.526000      3.341000
# Armenia                        31526.874667      3.186500
# Aruba                          42372.219173      3.770750
# Asia                           42372.219173      3.416433
# Asia (FAO)                     42372.219173      3.416433
# Australia                      21930.998333      2.354500
# Austria                        22291.806667      2.854750
# Azerbaijan                     42874.789667      2.434750

# %%
# To find the correlation among
# the columns using pearson method
df_corr = df_mean_values.corr(method ='pearson')
df_corr
# Out:
#                             aquaculture  capture fish    acute care  \
# aquaculture                1.000000e+00  8.731397e-01  2.890463e-01
# capture fish               8.731397e-01  1.000000e+00  9.655369e-02
# acute care                 2.890463e-01  9.655369e-02  1.000000e+00
# gender parity             -2.966992e-16 -7.280334e-16  1.228930e-15
# malnutrition standard age -1.478979e-02 -2.586943e-02  1.354467e-02
# malnutrition all ages     -1.666919e-02 -2.493556e-02  1.199403e-02
# gdp                        4.494910e-01  6.548911e-01  9.600999e-02
# cereals                    2.324102e-02  3.095935e-02  1.529269e-02
# disability life years     -2.533171e-02 -2.942567e-02  1.891042e-02
# healthy diet               1.109749e-02  9.618164e-03  8.597900e-04
#
#                            gender parity  malnutrition standard age  \
# aquaculture                -2.966992e-16              -1.478979e-02
# capture fish               -7.280334e-16              -2.586943e-02
# acute care                  1.228930e-15               1.354467e-02
# gender parity               1.000000e+00              -1.237130e-15
# malnutrition standard age  -1.237130e-15               1.000000e+00
# malnutrition all ages      -1.965746e-15               9.601999e-01
# gdp                        -3.578429e-15              -2.804872e-02
# cereals                    -2.392300e-15              -3.032781e-01
# disability life years      -1.281765e-15               6.417052e-01
# healthy diet               -1.481297e-15              -3.689918e-02
#
#                            malnutrition all ages           gdp       cereals  \
# aquaculture                        -1.666919e-02  4.494910e-01  2.324102e-02
# capture fish                       -2.493556e-02  6.548911e-01  3.095935e-02
# acute care                          1.199403e-02  9.600999e-02  1.529269e-02
# gender parity                      -1.965746e-15 -3.578429e-15 -2.392300e-15
# malnutrition standard age           9.601999e-01 -2.804872e-02 -3.032781e-01
# malnutrition all ages               1.000000e+00 -2.886660e-02 -3.220362e-01
# gdp                                -2.886660e-02  1.000000e+00  2.666184e-02
# cereals                            -3.220362e-01  2.666184e-02  1.000000e+00
# disability life years               6.837666e-01 -2.665773e-02 -4.663947e-01
# healthy diet                       -5.853407e-02  1.078567e-02 -7.728681e-02
#
#                            disability life years  healthy diet
# aquaculture                        -2.533171e-02  1.109749e-02
# capture fish                       -2.942567e-02  9.618164e-03
# acute care                          1.891042e-02  8.597900e-04
# gender parity                      -1.281765e-15 -1.481297e-15
# malnutrition standard age           6.417052e-01 -3.689918e-02
# malnutrition all ages               6.837666e-01 -5.853407e-02
# gdp                                -2.665773e-02  1.078567e-02
# cereals                            -4.663947e-01 -7.728681e-02
# disability life years               1.000000e+00 -4.515926e-03
# healthy diet                       -4.515926e-03  1.000000e+00

# %%
# To find the correlation among
# the columns using kendall method
df_kendall = df_corr.corr(method='kendall')
df_kendall
# Out:
#                            aquaculture  capture fish  acute care  \
# aquaculture                   1.000000      0.911111    0.466667
# capture fish                  0.911111      1.000000    0.377778
# acute care                    0.466667      0.377778    1.000000
# gender parity                 0.066667     -0.022222    0.155556
# malnutrition standard age    -0.333333     -0.422222    0.022222
# malnutrition all ages        -0.377778     -0.377778   -0.022222
# gdp                           0.777778      0.777778    0.422222
# cereals                       0.688889      0.688889    0.155556
# disability life years        -0.644444     -0.644444   -0.111111
# healthy diet                  0.466667      0.377778    0.200000
#
#                            gender parity  malnutrition standard age  \
# aquaculture                     0.066667                  -0.333333
# capture fish                   -0.022222                  -0.422222
# acute care                      0.155556                   0.022222
# gender parity                   1.000000                   0.244444
# malnutrition standard age       0.244444                   1.000000
# malnutrition all ages           0.200000                   0.955556
# gdp                            -0.066667                  -0.555556
# cereals                        -0.066667                  -0.555556
# disability life years           0.111111                   0.688889
# healthy diet                    0.155556                  -0.422222
#
#                            malnutrition all ages       gdp   cereals  \
# aquaculture                            -0.377778  0.777778  0.688889
# capture fish                           -0.377778  0.777778  0.688889
# acute care                             -0.022222  0.422222  0.155556
# gender parity                           0.200000 -0.066667 -0.066667
# malnutrition standard age               0.955556 -0.555556 -0.555556
# malnutrition all ages                   1.000000 -0.600000 -0.600000
# gdp                                    -0.600000  1.000000  0.644444
# cereals                                -0.600000  0.644444  1.000000
# disability life years                   0.733333 -0.600000 -0.866667
# healthy diet                           -0.466667  0.511111  0.155556
#
#                            disability life years  healthy diet
# aquaculture                            -0.644444      0.466667
# capture fish                           -0.644444      0.377778
# acute care                             -0.111111      0.200000
# gender parity                           0.111111      0.155556
# malnutrition standard age               0.688889     -0.422222
# malnutrition all ages                   0.733333     -0.466667
# gdp                                    -0.600000      0.511111
# cereals                                -0.866667      0.155556
# disability life years                   1.000000     -0.200000
# healthy diet                           -0.200000      1.000000

# %%
#import two more libraries
from pylab import rcParams
import seaborn as sb

# %%
#Now what does this mean??
#The dark shades indicate a strong negative corelation
#The lighter shades indicate a strong positive corelation
#i.e if any variable is plotted against itself, it'll have a corelation of 1
rcParams['figure.figsize'] = 14.7,8.27
sb.heatmap(df_kendall, 
           xticklabels=df_kendall.columns.values, 
           yticklabels=df_kendall.columns.values, 
           cmap="YlGnBu",
          annot=True)

# %%
#how to find correlation between different csv files
correlation = df_kendall["acute care"].corr(df_kendall["gdp"])

correlation
# Out:
# 0.6289893950358079

# %%
#snippet correlation
corr = df_kendall.corr()

corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6c59c_row0_col0, #T_6c59c_row0_col1, #T_6c59c_row1_col0, #T_6c59c_row1_col1, #T_6c59c_row2_col2, #T_6c59c_row3_col3, #T_6c59c_row4_col4, #T_6c59c_row4_col5, #T_6c59c_row5_col4, #T_6c59c_row5_col5, #T_6c59c_row6_col6, #T_6c59c_row7_col7, #T_6c59c_row8_col8, #T_6c59c_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col2 {
#   background-color: #f39475;
#   color: #000000;
# }
# #T_6c59c_row0_col3, #T_6c59c_row5_col7 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col4, #T_6c59c_row1_col5, #T_6c59c_row4_col0, #T_6c59c_row4_col1, #T_6c59c_row4_col2, #T_6c59c_row5_col0 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col5, #T_6c59c_row1_col4, #T_6c59c_row7_col4, #T_6c59c_row7_col5 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col6, #T_6c59c_row1_col6, #T_6c59c_row6_col0, #T_6c59c_row6_col1 {
#   background-color: #b8122a;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col7, #T_6c59c_row7_col0 {
#   background-color: #bb1b2c;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col8, #T_6c59c_row1_col8 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_6c59c_row0_col9 {
#   background-color: #df634e;
#   color: #f1f1f1;
# }
# #T_6c59c_row1_col2 {
#   background-color: #f59c7d;
#   color: #000000;
# }
# #T_6c59c_row1_col3, #T_6c59c_row4_col6, #T_6c59c_row4_col9, #T_6c59c_row5_col6, #T_6c59c_row5_col9, #T_6c59c_row6_col3, #T_6c59c_row6_col4, #T_6c59c_row6_col5, #T_6c59c_row7_col8, #T_6c59c_row8_col0, #T_6c59c_row8_col1, #T_6c59c_row8_col2, #T_6c59c_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_6c59c_row1_col7, #T_6c59c_row7_col1 {
#   background-color: #ba162b;
#   color: #f1f1f1;
# }
# #T_6c59c_row1_col9 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col0 {
#   background-color: #eb7d62;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col1 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_6c59c_row2_col5, #T_6c59c_row3_col2 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col6 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col7 {
#   background-color: #f39778;
#   color: #000000;
# }
# #T_6c59c_row2_col8 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_6c59c_row2_col9 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_6c59c_row3_col0 {
#   background-color: #a1c0ff;
#   color: #000000;
# }
# #T_6c59c_row3_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_6c59c_row3_col4 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_6c59c_row3_col5 {
#   background-color: #f7b79b;
#   color: #000000;
# }
# #T_6c59c_row3_col6 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_6c59c_row3_col7 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_6c59c_row3_col8 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_6c59c_row3_col9 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_6c59c_row4_col3 {
#   background-color: #ead4c8;
#   color: #000000;
# }
# #T_6c59c_row4_col7 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_6c59c_row4_col8, #T_6c59c_row6_col7, #T_6c59c_row7_col6, #T_6c59c_row8_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_6c59c_row5_col1, #T_6c59c_row7_col3 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_6c59c_row5_col2, #T_6c59c_row6_col8 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_6c59c_row5_col3 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_6c59c_row5_col8, #T_6c59c_row8_col5 {
#   background-color: #bd1f2d;
#   color: #f1f1f1;
# }
# #T_6c59c_row6_col2 {
#   background-color: #f39577;
#   color: #000000;
# }
# #T_6c59c_row6_col9 {
#   background-color: #d65244;
#   color: #f1f1f1;
# }
# #T_6c59c_row7_col2 {
#   background-color: #f7b194;
#   color: #000000;
# }
# #T_6c59c_row7_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_6c59c_row8_col3 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_6c59c_row8_col6 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_6c59c_row8_col9 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col0 {
#   background-color: #de614d;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col1 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col2 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_6c59c_row9_col3 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col4, #T_6c59c_row9_col5 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col6 {
#   background-color: #d55042;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col7 {
#   background-color: #e8765c;
#   color: #f1f1f1;
# }
# #T_6c59c_row9_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6c59c_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >aquaculture</th>
#       <th class="col_heading level0 col1" >capture fish</th>
#       <th class="col_heading level0 col2" >acute care</th>
#       <th class="col_heading level0 col3" >gender parity</th>
#       <th class="col_heading level0 col4" >malnutrition standard age</th>
#       <th class="col_heading level0 col5" >malnutrition all ages</th>
#       <th class="col_heading level0 col6" >gdp</th>
#       <th class="col_heading level0 col7" >cereals</th>
#       <th class="col_heading level0 col8" >disability life years</th>
#       <th class="col_heading level0 col9" >healthy diet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c59c_level0_row0" class="row_heading level0 row0" >aquaculture</th>
#       <td id="T_6c59c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_6c59c_row0_col1" class="data row0 col1" >0.994670</td>
#       <td id="T_6c59c_row0_col2" class="data row0 col2" >0.637759</td>
#       <td id="T_6c59c_row0_col3" class="data row0 col3" >-0.370848</td>
#       <td id="T_6c59c_row0_col4" class="data row0 col4" >-0.919705</td>
#       <td id="T_6c59c_row0_col5" class="data row0 col5" >-0.921087</td>
#       <td id="T_6c59c_row0_col6" class="data row0 col6" >0.973749</td>
#       <td id="T_6c59c_row0_col7" class="data row0 col7" >0.958651</td>
#       <td id="T_6c59c_row0_col8" class="data row0 col8" >-0.972405</td>
#       <td id="T_6c59c_row0_col9" class="data row0 col9" >0.752770</td>
#     </tr>
#     <tr>
#       <th id="T_6c59c_level0_row1" class="row_heading level0 row1" >capture fish</th>
#       <td id="T_6c59c_row1_col0" class="data row1 col0" >0.994670</td>
#       <td id="T_6c59c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_6c59c_row1_col2" class="data row1 col2" >0.605683</td>
#       <td id="T_6c59c_row1_col3" class="data row1 col3" >-0.414045</td>
#       <td id="T_6c59c_row1_col4" class="data row1 col4" >-0.921220</td>
#       <td id="T_6c59c_row1_col5" class="data row1 col5" >-0.917039</td>
#       <td id="T_6c59c_row1_col6" class="data row1 col6" >0.972244</td>
#       <td id="T_6c59c_row1_col7" class="data row1 col7" >0.962205</td>
#       <td id="T_6c59c_row1_col8" class="data row1 col8" >-0.972243</td>
#       <td id="T_6c59c_row1_col9" class="data row1 col9" >0.727775</td>
#     </tr>
#     <tr>
#       <th id="T_6c59c_level0_row2" class="row_heading level0 row2" >acute care</th>
#       <td id="T_6c59c_row2_col0" class="data row2 col0" >0.637759</td>
#       <td id="T_6c59c_row2_col1" class="data row2 col1" >0.605683</td>
#       <td id="T_6c59c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_6c59c_row2_col3" class="data row2 col3" >-0.178041</td>
#       <td id="T_6c59c_row2_col4" class="data row2 col4" >-0.500391</td>
#       <td id="T_6c59c_row2_col5" class="data row2 col5" >-0.513260</td>
#       <td id="T_6c59c_row2_col6" class="data row2 col6" >0.628989</td>
#       <td id="T_6c59c_row2_col7" class="data row2 col7" >0.514141</td>
#       <td id="T_6c59c_row2_col8" class="data row2 col8" >-0.537996</td>
#       <td id="T_6c59c_row2_col9" class="data row2 col9" >0.439991</td>
#     </tr>
#     <tr>
#       <th id="T_6c59c_level0_row3" class="row_heading level0 row3" >gender parity</th>
#       <td id="T_6c59c_row3_col0" class="data row3 col0" >-

# %%
#plot correlation heatmap
sns.heatmap(df_kendall.corr())

plt.savefig("Plotting_Correlation_HeatMap.jpg")

# %%
#give name to axes labels heatmap
hm = sns.heatmap(df_kendall.corr(), annot = True)

hm.set(xlabel='ways wurth dying for', ylabel='deathrates', title = "make funeral owners happy")

plt.show()

# %% [markdown]
# #header

# %%
#down here i put some examples about how to compare correlation between different dataframes
# use the function regplot to make a scatterplot correlation between gdp and acute care
sns.regplot(x=df_kendall["acute care"], y=df_kendall["gdp"])

plt.savefig("Plotting_Correlation_Scatterplot_With_Regression_Fit.jpg")

# %%
# use the function regplot to make a scatterplot correlation between disability life years and aquaculture
sns.regplot(x=df_kendall["aquaculture"], y=df_kendall["disability life years"], fit_reg=False)

plt.savefig("Plotting_Correlation_Scatterplot_Without_Regression_Fit.jpg")

# %%
#correlation between cereals and malnutrition standard age
sns.regplot(x=df_kendall["cereals"], y=df_kendall["malnutrition standard age"])

# %%
#put multiple tables in plot
fig, axs = plt.subplots(ncols=3)
sns.regplot(x='aquaculture', y='healthy diet', data=df_kendall, ax=axs[0])
sns.regplot(x='capture fish', y='disability life years', data=df_kendall, ax=axs[1])
sns.boxplot(x='acute care',y='cereals', data=df_kendall, ax=axs[2])
sns.boxplot(x='gender parity', y='gdp', data=df_kendall, ax=axs[2])

# %%
#making a color bar
f = plt.figure(figsize=(19, 15))
plt.matshow(df_kendall.corr(), fignum=f.number)
plt.xticks(range(df_kendall.select_dtypes(['number']).shape[1]), df_kendall.select_dtypes(['number']).columns, fontsize=14, rotation=45)
plt.yticks(range(df_kendall.select_dtypes(['number']).shape[1]), df_kendall.select_dtypes(['number']).columns, fontsize=14)
cb = plt.colorbar()
cb.ax.tick_params(labelsize=14)
plt.title('mortuality', fontsize=16);

# %%
#limiting the digit precision
df_kendall.style.background_gradient(cmap='coolwarm').set_precision(2)
# Out:
# <ipython-input-34-757a29d5e4f7>:2: FutureWarning: this method is deprecated in favour of `Styler.format(precision=..)`
#   df_kendall.style.background_gradient(cmap='coolwarm').set_precision(2)
# <style type="text/css">
# #T_c8d63_row0_col0, #T_c8d63_row1_col1, #T_c8d63_row2_col2, #T_c8d63_row3_col3, #T_c8d63_row4_col4, #T_c8d63_row5_col5, #T_c8d63_row6_col6, #T_c8d63_row7_col7, #T_c8d63_row8_col8, #T_c8d63_row9_col9 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col1, #T_c8d63_row1_col0 {
#   background-color: #c73635;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col2 {
#   background-color: #e2dad5;
#   color: #000000;
# }
# #T_c8d63_row0_col3 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col4, #T_c8d63_row5_col7, #T_c8d63_row6_col8 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col5, #T_c8d63_row1_col5 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col6, #T_c8d63_row1_col6 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col7, #T_c8d63_row1_col7, #T_c8d63_row4_col8, #T_c8d63_row8_col5 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col8, #T_c8d63_row1_col8, #T_c8d63_row4_col2 {
#   background-color: #5f7fe8;
#   color: #f1f1f1;
# }
# #T_c8d63_row0_col9 {
#   background-color: #f5c1a9;
#   color: #000000;
# }
# #T_c8d63_row1_col2 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_c8d63_row1_col3 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_c8d63_row1_col4, #T_c8d63_row9_col4, #T_c8d63_row9_col5 {
#   background-color: #5470de;
#   color: #f1f1f1;
# }
# #T_c8d63_row1_col9 {
#   background-color: #eed0c0;
#   color: #000000;
# }
# #T_c8d63_row2_col0, #T_c8d63_row9_col0 {
#   background-color: #f7b599;
#   color: #000000;
# }
# #T_c8d63_row2_col1, #T_c8d63_row9_col1 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_c8d63_row2_col3, #T_c8d63_row9_col3 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_c8d63_row2_col4 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_c8d63_row2_col5 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_c8d63_row2_col6 {
#   background-color: #f5c0a7;
#   color: #000000;
# }
# #T_c8d63_row2_col7, #T_c8d63_row9_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_c8d63_row2_col8 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# #T_c8d63_row2_col9 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_c8d63_row3_col0 {
#   background-color: #cad8ef;
#   color: #000000;
# }
# #T_c8d63_row3_col1 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_c8d63_row3_col2, #T_c8d63_row7_col2 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_c8d63_row3_col4 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_c8d63_row3_col5 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_c8d63_row3_col6 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_c8d63_row3_col7 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_c8d63_row3_col8 {
#   background-color: #e3d9d3;
#   color: #000000;
# }
# #T_c8d63_row3_col9, #T_c8d63_row7_col9 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_c8d63_row4_col0 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_c8d63_row4_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_c8d63_row4_col3 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_c8d63_row4_col5, #T_c8d63_row5_col4 {
#   background-color: #be242e;
#   color: #f1f1f1;
# }
# #T_c8d63_row4_col6, #T_c8d63_row4_col9 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_c8d63_row4_col7, #T_c8d63_row8_col3 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_c8d63_row5_col0, #T_c8d63_row5_col1 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_c8d63_row5_col2 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_c8d63_row5_col3 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_c8d63_row5_col6, #T_c8d63_row5_col9, #T_c8d63_row6_col3, #T_c8d63_row6_col4, #T_c8d63_row6_col5, #T_c8d63_row7_col3, #T_c8d63_row7_col4, #T_c8d63_row7_col5, #T_c8d63_row7_col8, #T_c8d63_row8_col0, #T_c8d63_row8_col1, #T_c8d63_row8_col2, #T_c8d63_row8_col6, #T_c8d63_row8_col7 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_c8d63_row5_col8 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_c8d63_row6_col0, #T_c8d63_row6_col1 {
#   background-color: #e0654f;
#   color: #f1f1f1;
# }
# #T_c8d63_row6_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_c8d63_row6_col7, #T_c8d63_row7_col0, #T_c8d63_row7_col1 {
#   background-color: #ec7f63;
#   color: #f1f1f1;
# }
# #T_c8d63_row6_col9 {
#   background-color: #f7b89c;
#   color: #000000;
# }
# #T_c8d63_row7_col6 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_c8d63_row8_col4 {
#   background-color: #ee8468;
#   color: #f1f1f1;
# }
# #T_c8d63_row8_col9 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_c8d63_row9_col2 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_c8d63_row9_col6 {
#   background-color: #f7af91;
#   color: #000000;
# }
# #T_c8d63_row9_col8 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# </style>
# <table id="T_c8d63_" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >aquaculture</th>
#       <th class="col_heading level0 col1" >capture fish</th>
#       <th class="col_heading level0 col2" >acute care</th>
#       <th class="col_heading level0 col3" >gender parity</th>
#       <th class="col_heading level0 col4" >malnutrition standard age</th>
#       <th class="col_heading level0 col5" >malnutrition all ages</th>
#       <th class="col_heading level0 col6" >gdp</th>
#       <th class="col_heading level0 col7" >cereals</th>
#       <th class="col_heading level0 col8" >disability life years</th>
#       <th class="col_heading level0 col9" >healthy diet</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8d63_level0_row0" class="row_heading level0 row0" >aquaculture</th>
#       <td id="T_c8d63_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_c8d63_row0_col1" class="data row0 col1" >0.91</td>
#       <td id="T_c8d63_row0_col2" class="data row0 col2" >0.47</td>
#       <td id="T_c8d63_row0_col3" class="data row0 col3" >0.07</td>
#       <td id="T_c8d63_row0_col4" class="data row0 col4" >-0.33</td>
#       <td id="T_c8d63_row0_col5" class="data row0 col5" >-0.38</td>
#       <td id="T_c8d63_row0_col6" class="data row0 col6" >0.78</td>
#       <td id="T_c8d63_row0_col7" class="data row0 col7" >0.69</td>
#       <td id="T_c8d63_row0_col8" class="data row0 col8" >-0.64</td>
#       <td id="T_c8d63_row0_col9" class="data row0 col9" >0.47</td>
#     </tr>
#     <tr>
#       <th id="T_c8d63_level0_row1" class="row_heading level0 row1" >capture fish</th>
#       <td id="T_c8d63_row1_col0" class="data row1 col0" >0.91</td>
#       <td id="T_c8d63_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_c8d63_row1_col2" class="data row1 col2" >0.38</td>
#       <td id="T_c8d63_row1_col3" class="data row1 col3" >-0.02</td>
#       <td id="T_c8d63_row1_col4" class="data row1 col4" >-0.42</td>
#       <td id="T_c8d63_row1_col5" class="data row1 col5" >-0.38</td>
#       <td id="T_c8d63_row1_col6" class="data row1 col6" >0.78</td>
#       <td id="T_c8d63_row1_col7" class="data row1 col7" >0.69</td>
#       <td id="T_c8d63_row1_col8" class="data row1 col8" >-0.64</td>
#       <td id="T_c8d63_row1_col9" class="data row1 col9" >0.38</td>
#     </tr>
#     <tr>
#       <th id="T_c8d63_level0_row2" class="row_heading level0 row2" >acute care</th>
#       <td id="T_c8d63_row2_col0" class="data row2 col0" >0.47</td>
#       <td id="T_c8d63_row2_col1" class="data row2 col1" >0.38</td>
#       <td id="T_c8d63_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_c8d63_row2_col3" class="data row2 col3" >0.16</td>
#       <td id="T_c8d63_row2_col4" class="data row2 col4" >0.02</td>
#       <td id="T_c8d63_row2_col5" class="data row2 col5" >-0.02</td>
#       <td id="T_c8d63_row2_col6" class="data row2 col6" >0.42</td>
#       <td id="T_c8d63_row2_col7" class="data row2 col7" >0.16</td>
#       <td id="T_c8d63_row2_col8" class="data row2 col8" >-0.11</td>
#       <td id="T_c8d63_row2_col9" class="data row2 col9" >0.20</td>
#     </tr>
#     <tr>
#       <th id="T_c8d63_level0_row3" class="row_heading level0 row3" >gender parity</th>
#       <td id="T_c8d63_row3_col0" class="data row3 col0" >0.07</td>
#       <td id="T_c8d63_row3_col1" class="data row3 col1" >-0.02</

# %%
#conclusion is not eating the food, but food production creates the most co2 output, looking at the fishing industry but also our new way so called healthy food like vegetarian and vegan ('Healthy diet'),
#is a big polluter industry. So stay normal and eat normal food like omnivores because its the variously type of food relieves load correctly the co3 output globaly. See the public health industry it's very less
#carrying for the global co2 output('acute care' and 'disability life years'), also gdp is a bit determine in the output but it's less disturbing comparable then cereals output globally
